# %% [markdown]
# # Assignment 2: IR

# %% [markdown]
# ## Preparations
# * Put all your imports, and path constants in the next cells
# * Make sure all your path constants are **relative to** ***DATA_DIR*** and **NOT hard-coded** in your code.

# %%
# imports
# Put all your imports here
from whoosh import index, writing
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
from whoosh.analysis import *
from whoosh.qparser import QueryParser
import os.path
from pathlib import Path
import tempfile
import subprocess

# %%
DATA_DIR = "government"
#
# Put other path constants here
#
DOCUMENTS_DIR = os.path.join(DATA_DIR, "documents")
TOPIC_FILE = os.path.join(DATA_DIR, "gov.topics")
QRELS_FILE = os.path.join(DATA_DIR, "gov.qrels")

# For windows:
TREC_EVAL = os.path.join("trec_eval", "trec_eval.exe")

# %% [markdown]
# ## Question 1
# Provide your text answers in the following two markdown cells

# %% [markdown]
# ### Q1 (a): Provide answer to Q1 (a) here [markdown cell]

# %% [markdown]
# Mean Average Precision (MAP)

# %% [markdown]
# ### Q1 (b): Provide answer to Q1 (b) here [markdown cell]

# %% [markdown]
# A government web site database is large and bound to house tons of documents, and a singular document or even a few will likely not cover all of the user’s information needs (ruling out recip_rank and P@5, P@10 etc.). A user researching a certain case or subject will likely want to read through all documents relevant to the query.
#
# Thus, the best measure should look not only at whether the system retrieves as many relevant documents as possible, but also the ranking of these documents, such that relevant documents are the best to come to the user’s attention --> this makes MAP the best measure for this purpose.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Q2 (a): Write your code below

# %%
# Put your code for creating the index here (you can add more cells).
# Make sure you save the final index in the variable INDEX_Q2, your query parser in QP_Q2, and your searcher in SEARCHER_Q2

def createIndex(schema):
    # Generate a temporary directory for the index
    indexDir = tempfile.mkdtemp()

    # create and return the index
    return index.create_in(indexDir, schema)

def addFilesToIndex(indexObj, fileList):
    # open writer
    writer = writing.BufferedWriter(indexObj, period=None, limit=1000)

    try:
        # write each file to index
        for docNum, filePath in enumerate(fileList):
            with open(filePath, "r", encoding="utf-8") as f:
                fileContent = f.read()
                writer.add_document(file_path = filePath,
                                    file_content = fileContent)

                # print status every 1000 documents
                if (docNum+1 % 1000 == 0):
                    print("already indexed:", docNum+1)
        print("done indexing.")

    finally:
        # close the index
        writer.close()

# first, define a Schema for the index
mySchema = Schema(file_path = ID(stored=True),
                  file_content = TEXT(analyzer = RegexTokenizer()))

# now, create the index at the path INDEX_DIR based on the new schema
myIndex = createIndex(mySchema)
        
# Build a list of files to index
filesToIndex = [str(filePath) for filePath in Path(DOCUMENTS_DIR).glob("**/*") if filePath.is_file()]

addFilesToIndex(myIndex, filesToIndex)
# Out:
# done indexing.

# %%
# count files to index
print("number of files:", len(filesToIndex))
# Out:
# number of files: 4078

# %%
# define a query parser for the field "file_content" in the index
myQueryParser = QueryParser("file_content", schema=myIndex.schema)
mySearcher = myIndex.searcher()

sampleQuery = myQueryParser.parse("topics")
sampleQueryResults = mySearcher.search(sampleQuery, limit=None)

# inspect the result:
# for each document print the rank and the score
for (docnum, result) in enumerate(sampleQueryResults):
    score = sampleQueryResults.score(docnum)
    fileName = os.path.basename(result["file_path"])
    print(fileName, docnum, score)
# Out:
# G00-38-4007589 0 7.587337532494129
# G00-15-1980890 1 7.303347484832998
# G00-52-2991521 2 7.273467259978599
# G00-28-3095840 3 6.990666413736417
# G00-94-3097702 4 6.838291228538814
# G00-70-0992046 5 6.8033986825647945
# G00-67-2771108 6 6.658953296962102
# G00-93-3702508 7 6.658953296962102
# G00-87-2843876 8 6.625902343114017
# G00-79-4144643 9 6.363019442848441
# G00-95-2757938 10 6.3460209424648175
# G00-03-2042174 11 6.2129536639850995
# G00-91-1609512 12 6.202081251266743
# G00-18-4042118 13 6.173469427536226
# G00-49-2029636 14 6.166262720519868
# G00-07-2819623 15 6.109819292317214
# G00-22-2864155 16 6.109819292317214
# G00-68-0320800 17 6.023497065426611
# G00-05-2948873 18 6.020163336230321
# G00-05-3703958 19 6.013288024988558
# G00-07-3972872 20 5.9863769693119
# G00-86-3214229 21 5.926443826929672
# G00-39-2879677 22 5.887255583637417
# G00-48-2946724 23 5.848520073541328
# G00-64-1861217 24 5.82291676450907
# G00-25-0870759 25 5.698544569625222
# G00-02-4047734 26 5.6204754094266605
# G00-10-2392581 27 5.6204754094266605
# G00-18-2123316 28 5.6204754094266605
# G00-70-3424520 29 5.620389353706836
# G00-01-0631689 30 5.579317686719785
# G00-35-1974416 31 5.579317686719785
# G00-04-2494323 32 5.538758363131637
# G00-11-2005001 33 5.538758363131637
# G00-23-0917457 34 5.538758363131637
# G00-00-2040865 35 5.498784482508491
# G00-74-2685794 36 5.409547116510644
# G00-01-2064929 37 5.36600583676733
# G00-66-0841001 38 5.36600583676733
# G00-18-2295266 39 5.323159885213812
# G00-23-1078147 40 5.323159885213812
# G00-29-0283205 41 5.323159885213812
# G00-96-1781066 42 5.323159885213812
# G00-97-2215955 43 5.323159885213812
# G00-65-0000000 44 5.275768770199545
# G00-80-2737758 45 5.229214037814248
# G00-64-2338458 46 5.211281227237252
# G00-04-3372687 47 5.183473740367533
# G00-00-2694952 48 5.138526691422147
# G00-36-3746009 49 5.138526691422147
# G00-59-2832535 50 5.138526691422147
# G00-96-2382474 51 5.138526691422147
# G00-65-3333979 52 5.089491020352254
# G00-03-1921890 53 5.041382373140296
# G00-05-2303988 54 5.041382373140296
# G00-14-1443227 55 5.041382373140296
# G00-39-0000000 56 5.041382373140296
# G00-54-3434200 57 5.041382373140296
# G00-70-3522936 58 5.041382373140296
# G00-48-2464830 59 4.999720255688765
# G00-45-0770756 60 4.989502521662079
# G00-47-1094341 61 4.989502521662079
# G00-17-2845878 62 4.938679564123619
# G00-29-3865087 63 4.909087800382322
# G00-10-0852358 64 4.888881529687295
# G00-89-2116689 65 4.888881529687295
# G00-06-1859727 66 4.835689287028721
# G00-27-3165010 67 4.835689287028721
# G00-91-3997333 68 4.835689287028721
# G00-59-3730691 69 4.7836420757109925
# G00-92-3815340 70 4.7836420757109925
# G00-81-1053799 71 4.783600516948262
# G00-02-0510219 72 4.732703317030539
# G00-49-1264822 73 4.720070247058827
# G00-02-3293233 74 4.678729918791294
# G00-02-3807812 75 4.678729918791294
# G00-34-2999931 76 4.678729918791294
# G00-01-3251318 77 4.625973702279907
# G00-09-0472163 78 4.625973702279907
# G00-24-0537894 79 4.625973702279907
# G00-97-1475424 80 4.625973702279907
# G00-65-4078383 81 4.594044502235655
# G00-04-0412407 82 4.574393952654824
# G00-27-2669897 83 4.574393952654824
# G00-01-2292288 84 4.516289984062455
# G00-10-3730888 85 4.516289984062455
# G00-13-1078618 86 4.516289984062455
# G00-21-3009650 87 4.516289984062455
# G00-61-4150601 88 4.516289984062455
# G00-74-1546702 89 4.516289984062455
# G00-84-3542587 90 4.516289984062455
# G00-88-3380937 91 4.40804081326599
# G00-82-2477299 92 4.360238725151955
# G00-01-0190637 93 4.35050942455146
# G00-01-0726854 94 4.35050942455146
# G00-05-0013004 95 4.35050942455146
# G00-10-4076121 96 4.35050942455146
# G00-45-0332043 97 4.35050942455146
# G00-55-2853576 98 4.35050942455146
# G00-90-0874739 99 4.324594481872395
# G00-04-3257250 100 4.2944604262396435
# G00-78-0686285 101 4.2944604262396435
# G00-81-3327332 102 4.2944604262396435
# G00-03-2784515 103 4.257846024265132
# G00-44-0550737 104 4.2398372527599495
# G00-72-0385489 105 4.2398372527599495
# G00-85-2732861 106 4.2398372527599495
# G00-73-1499832 107 4.183302367116144
# G00-76-3461519 108 4.183302367116144
# G00-90-0222848 109 4.125062358109217
# G00-44-2026102 110 4.010297740572289
# G00-69-1797385 111 4.010297740572289
# G00-94-1294899 112 4.010297740572289
# G00-57-0197281 113 3.9508822275881306
# G00-79-2864917 114 3.8932015804105915
# G00-05-2393778 115 3.8371809082229738
# G00-08-2045138 116 3.8371809082229738
# G00-86-3730053 117 3.7853997358433613
# G00-05-0081436 118 3.777391248799241
# G00-43-0913072 119 3.777391248799241
# G00-68-1850883 120 3.777391248799241
# G00-29-1544211 121 3.6607183589827774
# G00-35-1714937 122 3.6013920788734066
# G00-44-2717261 123 3.6013920788734066
# G00-58-3090637 124 3.6013920788734066
# G00-41-2516655 125 3.5439580381606444
# G00-41-1157769 126 3.518985685506916
# G00-34-1517989 127 3.4860470496823437
# G00-62-3597770 128 3.4860470496823437
# G00-75-1062837 129 3.4860470496823437
# G00-44-1176683 130 3.4299768848596512
# G00-45-4032177 131 3.4299768848596512
# G00-30-1592409 132 3.4277937634071596
# G00-56-1300001 133 3.4277937634071596
# G00-02-0832578 134 3.193788893413203
# G00-35-3882703 135 3.193788893413203
# G00-77-3788231 136 3.193788893413203
# G00-95-1976041 137 3.137425129685989
# G00-82-2554245 138 2.909767381027028
# G00-18-0270371 139 2.796850619019009
# G00-63-1804150 140 2.7422054206697797
# G00-94-1978508 141 2.7422054206697797
# G00-54-2576117 142 2.686944536146886
# G00-31-3447261 143 2.4715323545778247
# G00-19-4082665 144 2.4188491603698687
# G00-25-1502844 145 2.367313835957252
# G00-45-1367785 146 2.31591565684788
# G00-69-0779075 147 2.31591565684788
# G00-77-0645360 148 2.265738974328744
# G00-98-4068688 149 2.1998443827590894
# G00-30-3863788 150 2.16546533818969
# G00-45-0809730 151 2.16546533818969
# G00-16-0858333 152 2.068864630985893
# G00-23-3822276 153 2.068864630985893
# G00-60-0879221 154 2.068864630985893
# G00-17-0641985 155 2.021041684016068
# G00-86-1693753 156 1.8826393878386174
# G00-23-3963973 157 1.837875130237585
# G00-89-1075429 158 1.793379251069784
# G00-51-0815543 159 1.7504123025145362
# G00-21-1913322 160 1.6656774430284718
# G00-22-0354429 161 1.6656774430284718
# G00-78-1144993 162 1.6656774430284718
# G00-26-3218156 163 1.584048803132887
# G00-63-3078014 164 1.584048803132887
# G00-40-4123169 165 1.5049338822622182
# G00-70-3168895 166 1.3925525443161675
# G00-55-1952930 167 1.3564275717625345
# G00-21-0649032 168 1.2861025581480694
# G00-15-3429810 169 1.2522809273154742
# G00-87-3746944 170 1.2522780792394834
# G00-59-3622783 171 1.1865314682998005
# G00-04-0561356 172 1.0342148853174342
# G00-68-0439463 173 0.9244993852250064
# G00-10-3758881 174 0.7561920919573575
# G00-68-4089689 175 0.7345298176705352
# G00-78-2551063 176 0.546343496060796
# G00-18-2154531 177 0.4420552386178128
# G00-32-3296216 178 0.4420552386178128
# G00-33-2857182 179 0.3793038323142435
# G00-76-2323292 180 0.3352644888878028

# %%
INDEX_Q2 = myIndex # Replace None with your index for Q2
QP_Q2 = myQueryParser # Replace None with your query parser for Q2
SEARCHER_Q2 = mySearcher # Replace None with your searcher for Q2

# %%
sampleQueryResults
# Out:
# <Top 181 Results for Term('file_content', 'topics') runtime=0.005630000000564905>

# %%
# print the topic file
with open(TOPIC_FILE, "r") as f:
    print(f.read())
# Out:
# 1 mining gold silver coal
# 2 juvenile delinquency
# 4 wireless communications
# 6 physical therapists
# 7 cotton industry
# 9 genealogy searches
# 10 Physical Fitness
# 14 Agricultural biotechnology
# 16 Emergency and disaster preparedness assistance
# 18 Shipwrecks
# 19 Cybercrime, internet fraud, and cyber fraud
# 22 Veteran's Benefits
# 24 Air Bag Safety
# 26 Nuclear power plants
# 28 Early Childhood Education

# %%
# print the first 10 lines in the qrels file
with open(QRELS_FILE, "r") as f:
    qrels10 = f.readlines()[:10]
    print("".join(qrels10))
# Out:
# 1 0 G00-00-0681214 0
# 1 0 G00-00-0945765 0
# 1 0 G00-00-1006224 1
# 1 0 G00-00-1591495 0
# 1 0 G00-00-2764912 0
# 1 0 G00-00-3253540 0
# 1 0 G00-00-3717374 0
# 1 0 G00-01-0270065 0
# 1 0 G00-01-0400712 0
# 1 0 G00-01-0682299 0

# %%
def trecEval(topicFile, qrelsFile, queryParser, searcher):
    # Load topic file - a list of topics(search phrases) used for evalutation
    with open(topicFile, "r") as tf:
        topics = tf.read().splitlines()

    # create an output file to which we'll write our results
    tempOutputFile = tempfile.mkstemp()[1]
    with open(tempOutputFile, "w") as outputTRECFile:
        # for each evaluated topic:
        # build a query and record the results in the file in TREC_EVAL format
        for topic in topics:
            topic_id, topic_phrase = tuple(topic.split(" ", 1))
            topicQuery = queryParser.parse(topic_phrase)
            topicResults = searcher.search(topicQuery, limit=None)
            for (docnum, result) in enumerate(topicResults):
                score = topicResults.score(docnum)
                outputTRECFile.write("%s Q0 %s %d %lf test\n" % (topic_id, os.path.basename(result["file_path"]), docnum, score))
    
    result = subprocess.run([TREC_EVAL, '-q', qrelsFile, tempOutputFile], stdout=subprocess.PIPE)
    print(result.stdout.decode())

# %%
trecEval(TOPIC_FILE, QRELS_FILE, myQueryParser, mySearcher)
# Out:
# num_ret               	1	1
# num_rel               	1	5
# num_rel_ret           	1	0
# map                   	1	0.0000
# Rprec                 	1	0.0000
# bpref                 	1	0.0000
# recip_rank            	1	0.0000
# iprec_at_recall_0.00  	1	0.0000
# iprec_at_recall_0.10  	1	0.0000
# iprec_at_recall_0.20  	1	0.0000
# iprec_at_recall_0.30  	1	0.0000
# iprec_at_recall_0.40  	1	0.0000
# iprec_at_recall_0.50  	1	0.0000
# iprec_at_recall_0.60  	1	0.0000
# iprec_at_recall_0.70  	1	0.0000
# iprec_at_recall_0.80  	1	0.0000
# iprec_at_recall_0.90  	1	0.0000
# iprec_at_recall_1.00  	1	0.0000
# P_5                   	1	0.0000
# P_10                  	1	0.0000
# P_15                  	1	0.0000
# P_20                  	1	0.0000
# P_30                  	1	0.0000
# P_100                 	1	0.0000
# P_200                 	1	0.0000
# P_500                 	1	0.0000
# P_1000                	1	0.0000
# num_ret               	10	16
# num_rel               	10	1
# num_rel_ret           	10	1
# map                   	10	0.1667
# Rprec                 	10	0.0000
# bpref                 	10	0.0000
# recip_rank            	10	0.1667
# iprec_at_recall_0.00  	10	0.1667
# iprec_at_recall_0.10  	10	0.1667
# iprec_at_recall_0.20  	10	0.1667
# iprec_at_recall_0.30  	10	0.1667
# iprec_at_recall_0.40  	10	0.1667
# iprec_at_recall_0.50  	10	0.1667
# iprec_at_recall_0.60  	10	0.1667
# iprec_at_recall_0.70  	10	0.1667
# iprec_at_recall_0.80  	10	0.1667
# iprec_at_recall_0.90  	10	0.1667
# iprec_at_recall_1.00  	10	0.1667
# P_5                   	10	0.0000
# P_10                  	10	0.1000
# P_15                  	10	0.0667
# P_20                  	10	0.0500
# P_30                  	10	0.0333
# P_100                 	10	0.0100
# P_200                 	10	0.0050
# P_500                 	10	0.0020
# P_1000                	10	0.0010
# num_ret               	14	7
# num_rel               	14	1
# num_rel_ret           	14	1
# map                   	14	0.2500
# Rprec                 	14	0.0000
# bpref                 	14	0.0000
# recip_rank            	14	0.2500
# iprec_at_recall_0.00  	14	0.2500
# iprec_at_recall_0.10  	14	0.2500
# iprec_at_recall_0.20  	14	0.2500
# iprec_at_recall_0.30  	14	0.2500
# iprec_at_recall_0.40  	14	0.2500
# iprec_at_recall_0.50  	14	0.2500
# iprec_at_recall_0.60  	14	0.2500
# iprec_at_recall_0.70  	14	0.2500
# iprec_at_recall_0.80  	14	0.2500
# iprec_at_recall_0.90  	14	0.2500
# iprec_at_recall_1.00  	14	0.2500
# P_5                   	14	0.2000
# P_10                  	14	0.1000
# P_15                  	14	0.0667
# P_20                  	14	0.0500
# P_30                  	14	0.0333
# P_100                 	14	0.0100
# P_200                 	14	0.0050
# P_500                 	14	0.0020
# P_1000                	14	0.0010
# num_ret               	16	7
# num_rel               	16	7
# num_rel_ret           	16	0
# map                   	16	0.0000
# Rprec                 	16	0.0000
# bpref                 	16	0.0000
# recip_rank            	16	0.0000
# iprec_at_recall_0.00  	16	0.0000
# iprec_at_recall_0.10  	16	0.0000
# iprec_at_recall_0.20  	16	0.0000
# iprec_at_recall_0.30  	16	0.0000
# iprec_at_recall_0.40  	16	0.0000
# iprec_at_recall_0.50  	16	0.0000
# iprec_at_recall_0.60  	16	0.0000
# iprec_at_recall_0.70  	16	0.0000
# iprec_at_recall_0.80  	16	0.0000
# iprec_at_recall_0.90  	16	0.0000
# iprec_at_recall_1.00  	16	0.0000
# P_5                   	16	0.0000
# P_10                  	16	0.0000
# P_15                  	16	0.0000
# P_20                  	16	0.0000
# P_30                  	16	0.0000
# P_100                 	16	0.0000
# P_200                 	16	0.0000
# P_500                 	16	0.0000
# P_1000                	16	0.0000
# num_ret               	18	17
# num_rel               	18	1
# num_rel_ret           	18	1
# map                   	18	1.0000
# Rprec                 	18	1.0000
# bpref                 	18	1.0000
# recip_rank            	18	1.0000
# iprec_at_recall_0.00  	18	1.0000
# iprec_at_recall_0.10  	18	1.0000
# iprec_at_recall_0.20  	18	1.0000
# iprec_at_recall_0.30  	18	1.0000
# iprec_at_recall_0.40  	18	1.0000
# iprec_at_recall_0.50  	18	1.0000
# iprec_at_recall_0.60  	18	1.0000
# iprec_at_recall_0.70  	18	1.0000
# iprec_at_recall_0.80  	18	1.0000
# iprec_at_recall_0.90  	18	1.0000
# iprec_at_recall_1.00  	18	1.0000
# P_5                   	18	0.2000
# P_10                  	18	0.1000
# P_15                  	18	0.0667
# P_20                  	18	0.0500
# P_30                  	18	0.0333
# P_100                 	18	0.0100
# P_200                 	18	0.0050
# P_500                 	18	0.0020
# P_1000                	18	0.0010
# num_ret               	2	6
# num_rel               	2	2
# num_rel_ret           	2	0
# map                   	2	0.0000
# Rprec                 	2	0.0000
# bpref                 	2	0.0000
# recip_rank            	2	0.0000
# iprec_at_recall_0.00  	2	0.0000
# iprec_at_recall_0.10  	2	0.0000
# iprec_at_recall_0.20  	2	0.0000
# iprec_at_recall_0.30  	2	0.0000
# iprec_at_recall_0.40  	2	0.0000
# iprec_at_recall_0.50  	2	0.0000
# iprec_at_recall_0.60  	2	0.0000
# iprec_at_recall_0.70  	2	0.0000
# iprec_at_recall_0.80  	2	0.0000
# iprec_at_recall_0.90  	2	0.0000
# iprec_at_recall_1.00  	2	0.0000
# P_5                   	2	0.0000
# P_10                  	2	0.0000
# P_15                  	2	0.0000
# P_20                  	2	0.0000
# P_30                  	2	0.0000
# P_100                 	2	0.0000
# P_200                 	2	0.0000
# P_500                 	2	0.0000
# P_1000                	2	0.0000
# num_ret               	22	17
# num_rel               	22	1
# num_rel_ret           	22	1
# map                   	22	0.2000
# Rprec                 	22	0.0000
# bpref                 	22	0.0000
# recip_rank            	22	0.2000
# iprec_at_recall_0.00  	22	0.2000
# iprec_at_recall_0.10  	22	0.2000
# iprec_at_recall_0.20  	22	0.2000
# iprec_at_recall_0.30  	22	0.2000
# iprec_at_recall_0.40  	22	0.2000
# iprec_at_recall_0.50  	22	0.2000
# iprec_at_recall_0.60  	22	0.2000
# iprec_at_recall_0.70  	22	0.2000
# iprec_at_recall_0.80  	22	0.2000
# iprec_at_recall_0.90  	22	0.2000
# iprec_at_recall_1.00  	22	0.2000
# P_5                   	22	0.2000
# P_10                  	22	0.1000
# P_15                  	22	0.0667
# P_20                  	22	0.0500
# P_30                  	22	0.0333
# P_100                 	22	0.0100
# P_200                 	22	0.0050
# P_500                 	22	0.0020
# P_1000                	22	0.0010
# num_ret               	24	7
# num_rel               	24	1
# num_rel_ret           	24	1
# map                   	24	1.0000
# Rprec                 	24	1.0000
# bpref                 	24	1.0000
# recip_rank            	24	1.0000
# iprec_at_recall_0.00  	24	1.0000
# iprec_at_recall_0.10  	24	1.0000
# iprec_at_recall_0.20  	24	1.0000
# iprec_at_recall_0.30  	24	1.0000
# iprec_at_recall_0.40  	24	1.0000
# iprec_at_recall_0.50  	24	1.0000
# iprec_at_recall_0.60  	24	1.0000
# iprec_at_recall_0.70  	24	1.0000
# iprec_at_recall_0.80  	24	1.0000
# iprec_at_recall_0.90  	24	1.0000
# iprec_at_recall_1.00  	24	1.0000
# P_5                   	24	0.2000
# P_10                  	24	0.1000
# P_15                  	24	0.0667
# P_20                  	24	0.0500
# P_30                  	24	0.0333
# P_100                 	24	0.0100
# P_200                 	24	0.0050
# P_500                 	24	0.0020
# P_1000                	24	0.0010
# num_ret               	26	25
# num_rel               	26	3
# num_rel_ret           	26	1
# map                   	26	0.1111
# Rprec                 	26	0.3333
# bpref                 	26	0.1111
# recip_rank            	26	0.3333
# iprec_at_recall_0.00  	26	0.3333
# iprec_at_recall_0.10  	26	0.3333
# iprec_at_recall_0.20  	26	0.3333
# iprec_at_recall_0.30  	26	0.3333
# iprec_at_recall_0.40  	26	0.0000
# iprec_at_recall_0.50  	26	0.0000
# iprec_at_recall_0.60  	26	0.0000
# iprec_at_recall_0.70  	26	0.0000
# iprec_at_recall_0.80  	26	0.0000
# iprec_at_recall_0.90  	26	0.0000
# iprec_at_recall_1.00  	26	0.0000
# P_5                   	26	0.2000
# P_10                  	26	0.1000
# P_15                  	26	0.0667
# P_20                  	26	0.0500
# P_30                  	26	0.0333
# P_100                 	26	0.0100
# P_200                 	26	0.0050
# P_500                 	26	0.0020
# P_1000                	26	0.0010
# num_ret               	28	22
# num_rel               	28	2
# num_rel_ret           	28	0
# map                   	28	0.0000
# Rprec                 	28	0.0000
# bpref                 	28	0.0000
# recip_rank            	28	0.0000
# iprec_at_recall_0.00  	28	0.0000
# iprec_at_recall_0.10  	28	0.0000
# iprec_at_recall_0.20  	28	0.0000
# iprec_at_recall_0.30  	28	0.0000
# iprec_at_recall_0.40  	28	0.0000
# iprec_at_recall_0.50  	28	0.0000
# iprec_at_recall_0.60  	28	0.0000
# iprec_at_recall_0.70  	28	0.0000
# iprec_at_recall_0.80  	28	0.0000
# iprec_at_recall_0.90  	28	0.0000
# iprec_at_recall_1.00  	28	0.0000
# P_5                   	28	0.0000
# P_10                  	28	0.0000
# P_15                  	28	0.0000
# P_20                  	28	0.0000
# P_30                  	28	0.0000
# P_100                 	28	0.0000
# P_200                 	28	0.0000
# P_500                 	28	0.0000
# P_1000                	28	0.0000
# num_ret               	4	12
# num_rel               	4	4
# num_rel_ret           	4	1
# map                   	4	0.0312
# Rprec                 	4	0.0000
# bpref                 	4	0.0000
# recip_rank            	4	0.1250
# iprec_at_recall_0.00  	4	0.1250
# iprec_at_recall_0.10  	4	0.1250
# iprec_at_recall_0.20  	4	0.1250
# iprec_at_recall_0.30  	4	0.0000
# iprec_at_recall_0.40  	4	0.0000
# iprec_at_recall_0.50  	4	0.0000
# iprec_at_recall_0.60  	4	0.0000
# iprec_at_recall_0.70  	4	0.0000
# iprec_at_recall_0.80  	4	0.0000
# iprec_at_recall_0.90  	4	0.0000
# iprec_at_recall_1.00  	4	0.0000
# P_5                   	4	0.0000
# P_10                  	4	0.1000
# P_15                  	4	0.0667
# P_20                  	4	0.0500
# P_30                  	4	0.0333
# P_100                 	4	0.0100
# P_200                 	4	0.0050
# P_500                 	4	0.0020
# P_1000                	4	0.0010
# num_ret               	6	5
# num_rel               	6	1
# num_rel_ret           	6	0
# map                   	6	0.0000
# Rprec                 	6	0.0000
# bpref                 	6	0.0000
# recip_rank            	6	0.0000
# iprec_at_recall_0.00  	6	0.0000
# iprec_at_recall_0.10  	6	0.0000
# iprec_at_recall_0.20  	6	0.0000
# iprec_at_recall_0.30  	6	0.0000
# iprec_at_recall_0.40  	6	0.0000
# iprec_at_recall_0.50  	6	0.0000
# iprec_at_recall_0.60  	6	0.0000
# iprec_at_recall_0.70  	6	0.0000
# iprec_at_recall_0.80  	6	0.0000
# iprec_at_recall_0.90  	6	0.0000
# iprec_at_recall_1.00  	6	0.0000
# P_5                   	6	0.0000
# P_10                  	6	0.0000
# P_15                  	6	0.0000
# P_20                  	6	0.0000
# P_30                  	6	0.0000
# P_100                 	6	0.0000
# P_200                 	6	0.0000
# P_500                 	6	0.0000
# P_1000                	6	0.0000
# num_ret               	7	7
# num_rel               	7	3
# num_rel_ret           	7	0
# map                   	7	0.0000
# Rprec                 	7	0.0000
# bpref                 	7	0.0000
# recip_rank            	7	0.0000
# iprec_at_recall_0.00  	7	0.0000
# iprec_at_recall_0.10  	7	0.0000
# iprec_at_recall_0.20  	7	0.0000
# iprec_at_recall_0.30  	7	0.0000
# iprec_at_recall_0.40  	7	0.0000
# iprec_at_recall_0.50  	7	0.0000
# iprec_at_recall_0.60  	7	0.0000
# iprec_at_recall_0.70  	7	0.0000
# iprec_at_recall_0.80  	7	0.0000
# iprec_at_recall_0.90  	7	0.0000
# iprec_at_recall_1.00  	7	0.0000
# P_5                   	7	0.0000
# P_10                  	7	0.0000
# P_15                  	7	0.0000
# P_20                  	7	0.0000
# P_30                  	7	0.0000
# P_100                 	7	0.0000
# P_200                 	7	0.0000
# P_500                 	7	0.0000
# P_1000                	7	0.0000
# num_ret               	9	2
# num_rel               	9	1
# num_rel_ret           	9	0
# map                   	9	0.0000
# Rprec                 	9	0.0000
# bpref                 	9	0.0000
# recip_rank            	9	0.0000
# iprec_at_recall_0.00  	9	0.0000
# iprec_at_recall_0.10  	9	0.0000
# iprec_at_recall_0.20  	9	0.0000
# iprec_at_recall_0.30  	9	0.0000
# iprec_at_recall_0.40  	9	0.0000
# iprec_at_recall_0.50  	9	0.0000
# iprec_at_recall_0.60  	9	0.0000
# iprec_at_recall_0.70  	9	0.0000
# iprec_at_recall_0.80  	9	0.0000
# iprec_at_recall_0.90  	9	0.0000
# iprec_at_recall_1.00  	9	0.0000
# P_5                   	9	0.0000
# P_10                  	9	0.0000
# P_15                  	9	0.0000
# P_20                  	9	0.0000
# P_30                  	9	0.0000
# P_100                 	9	0.0000
# P_200                 	9	0.0000
# P_500                 	9	0.0000
# P_1000                	9	0.0000
# runid                 	all	test
# num_q                 	all	14
# num_ret               	all	151
# num_rel               	all	33
# num_rel_ret           	all	7
# map                   	all	0.1971
# gm_map                	all	0.0015
# Rprec                 	all	0.1667
# bpref                 	all	0.1508
# recip_rank            	all	0.2196
# iprec_at_recall_0.00  	all	0.2196
# iprec_at_recall_0.10  	all	0.2196
# iprec_at_recall_0.20  	all	0.2196
# iprec_at_recall_0.30  	all	0.2107
# iprec_at_recall_0.40  	all	0.1869
# iprec_at_recall_0.50  	all	0.1869
# iprec_at_recall_0.60  	all	0.1869
# iprec_at_recall_0.70  	all	0.1869
# iprec_at_recall_0.80  	all	0.1869
# iprec_at_recall_0.90  	all	0.1869
# iprec_at_recall_1.00  	all	0.1869
# P_5                   	all	0.0714
# P_10                  	all	0.0500
# P_15                  	all	0.0333
# P_20                  	all	0.0250
# P_30                  	all	0.0167
# P_100                 	all	0.0050
# P_200                 	all	0.0025
# P_500                 	all	0.0010
# P_1000                	all	0.0005

# %% [markdown]
# ### Q2 (b): Provide answer to Q2 (b) here [markdown cell]

# %% [markdown]
# MAP for all query results = 0.1971

# %% [markdown]
# ### Q2 (c): Provide answer to Q2(c) here [markdown cell]

# %% [markdown]
# Performed well – Query ID 18 and 24 (score of 1.0),
# Performed poorly – Query ID 1, 16, 2, 28, 6, 7, 9 (score of 0)

# %% [markdown]
# ## Question 3

# %%
sampleQuery = QP_Q2.parse("wireless communications")
sampleQueryResults = mySearcher.search(sampleQuery, limit=None)

print("Retrieved Documents:")

for (docnum, result) in enumerate(sampleQueryResults):
    score = sampleQueryResults.score(docnum)
    fileName = os.path.basename(result["file_path"])
    print(fileName, docnum, score)
# Out:
# Retrieved Documents:
# G00-99-2247765 0 16.44915453547273
# G00-85-1525415 1 13.364613279303013
# G00-05-1218739 2 12.956313628711154
# G00-09-0774298 3 11.781349226871903
# G00-56-4151981 4 11.367247611926537
# G00-21-2229498 5 10.743957712158082
# G00-98-4068688 6 10.46486548752591
# G00-47-2117970 7 10.213356414484583
# G00-67-0152545 8 8.392871246133646
# G00-06-1757034 9 6.4315561377014046
# G00-78-2551063 10 3.955775319427501
# G00-84-0274223 11 2.0684375138105002

# %%
with open(QRELS_FILE, "r") as f:
    qrelsAll = f.readlines()

print("Relevant Documents:")
for line in qrelsAll:
    if line.startswith('4') and line.endswith('1\n'):
        print(line)

print("Only Rank 8: G00-47-2117970 is actually relevant")
# Out:
# Relevant Documents:
# 4 0 G00-03-2855342 1
#
# 4 0 G00-36-1275993 1
#
# 4 0 G00-47-2117970 1
#
# 4 0 G00-65-0162935 1
#
# Only Rank 8: G00-47-2117970 is actually relevant

# %% [markdown]
# ### Q3 (a): Provide answer to Q3 (a) here [markdown cell]

# %% [markdown]
# Query 4:
#
#
# False positive: G00-84-0274223 (Not relevant but retrieved)
#     The word "wireless" appeared once, and "communications" appeared multiple times, but were infrequent especially relative to the length of the document.
#
#
# False negative: G00-36-1275993 (Relevant but not retrieved)
#     The words "wireless" and "communications" in this were often capitalized (as opposed to lowercase in the query). Also, the words telecommunications, which are similar in meaning to communications but not the same word, were also used very frequently.
#
# Thus, adapting queries/documents to case sensitivity/insensitivity, as well as stemming/lemmatization may help.

# %% [markdown]
# ### Q3 (b): Write your code below

# %%
import nltk
from nltk.stem import *

# download required resources
nltk.download("wordnet")

lrStem = LancasterStemmer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nicolwon\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Dont change this! Use it as-is in your code
# This filter will run for both the index and the query
from whoosh.analysis import Filter
class CustomFilter(Filter):
    is_morph = True
    def __init__(self, filterFunc, *args, **kwargs):
        self.customFilter = filterFunc
        self.args = args
        self.kwargs = kwargs
    def __eq__(self):
        return (other
                and self.__class__ is other.__class__)
    def __call__(self, tokens):
        for t in tokens:
            if t.mode == 'query': # if called by query parser
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t
            else: # == 'index' if called by indexer
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t

# %%
# Example1: Whoosh filter for NLTK's LancasterStemmer
myFilter1 = RegexTokenizer() | CustomFilter(LancasterStemmer().stem) | LowercaseFilter()

# %%
# Put your code for creating the index here (you can add more cells).
# Make sure you save the final index in the variable INDEX_Q3, your query parser in QP_Q3, and your searcher in SEARCHER_Q3

# define a Schema with the new analyzer
mySchema2 = Schema(file_path = ID(stored=True),
                   file_content = TEXT(analyzer = myFilter1))

# create the index based on the new schema
myIndex2 = createIndex(mySchema2)

addFilesToIndex(myIndex2, filesToIndex)
# Out:
# done indexing.

# %%
INDEX_Q3 = myIndex2 # Replace None with your index for Q3
QP_Q3 = QueryParser("file_content", schema=INDEX_Q3.schema) # Replace None with your query parser for Q3
SEARCHER_Q3 = INDEX_Q3.searcher() # Replace None with your searcher for Q3

# %%
trecEval(TOPIC_FILE, QRELS_FILE, QP_Q3, SEARCHER_Q3)
# Out:
# num_ret               	1	3
# num_rel               	1	5
# num_rel_ret           	1	0
# map                   	1	0.0000
# Rprec                 	1	0.0000
# bpref                 	1	0.0000
# recip_rank            	1	0.0000
# iprec_at_recall_0.00  	1	0.0000
# iprec_at_recall_0.10  	1	0.0000
# iprec_at_recall_0.20  	1	0.0000
# iprec_at_recall_0.30  	1	0.0000
# iprec_at_recall_0.40  	1	0.0000
# iprec_at_recall_0.50  	1	0.0000
# iprec_at_recall_0.60  	1	0.0000
# iprec_at_recall_0.70  	1	0.0000
# iprec_at_recall_0.80  	1	0.0000
# iprec_at_recall_0.90  	1	0.0000
# iprec_at_recall_1.00  	1	0.0000
# P_5                   	1	0.0000
# P_10                  	1	0.0000
# P_15                  	1	0.0000
# P_20                  	1	0.0000
# P_30                  	1	0.0000
# P_100                 	1	0.0000
# P_200                 	1	0.0000
# P_500                 	1	0.0000
# P_1000                	1	0.0000
# num_ret               	10	54
# num_rel               	10	1
# num_rel_ret           	10	1
# map                   	10	0.2500
# Rprec                 	10	0.0000
# bpref                 	10	0.0000
# recip_rank            	10	0.2500
# iprec_at_recall_0.00  	10	0.2500
# iprec_at_recall_0.10  	10	0.2500
# iprec_at_recall_0.20  	10	0.2500
# iprec_at_recall_0.30  	10	0.2500
# iprec_at_recall_0.40  	10	0.2500
# iprec_at_recall_0.50  	10	0.2500
# iprec_at_recall_0.60  	10	0.2500
# iprec_at_recall_0.70  	10	0.2500
# iprec_at_recall_0.80  	10	0.2500
# iprec_at_recall_0.90  	10	0.2500
# iprec_at_recall_1.00  	10	0.2500
# P_5                   	10	0.2000
# P_10                  	10	0.1000
# P_15                  	10	0.0667
# P_20                  	10	0.0500
# P_30                  	10	0.0333
# P_100                 	10	0.0100
# P_200                 	10	0.0050
# P_500                 	10	0.0020
# P_1000                	10	0.0010
# num_ret               	14	26
# num_rel               	14	1
# num_rel_ret           	14	1
# map                   	14	1.0000
# Rprec                 	14	1.0000
# bpref                 	14	1.0000
# recip_rank            	14	1.0000
# iprec_at_recall_0.00  	14	1.0000
# iprec_at_recall_0.10  	14	1.0000
# iprec_at_recall_0.20  	14	1.0000
# iprec_at_recall_0.30  	14	1.0000
# iprec_at_recall_0.40  	14	1.0000
# iprec_at_recall_0.50  	14	1.0000
# iprec_at_recall_0.60  	14	1.0000
# iprec_at_recall_0.70  	14	1.0000
# iprec_at_recall_0.80  	14	1.0000
# iprec_at_recall_0.90  	14	1.0000
# iprec_at_recall_1.00  	14	1.0000
# P_5                   	14	0.2000
# P_10                  	14	0.1000
# P_15                  	14	0.0667
# P_20                  	14	0.0500
# P_30                  	14	0.0333
# P_100                 	14	0.0100
# P_200                 	14	0.0050
# P_500                 	14	0.0020
# P_1000                	14	0.0010
# num_ret               	16	33
# num_rel               	16	7
# num_rel_ret           	16	0
# map                   	16	0.0000
# Rprec                 	16	0.0000
# bpref                 	16	0.0000
# recip_rank            	16	0.0000
# iprec_at_recall_0.00  	16	0.0000
# iprec_at_recall_0.10  	16	0.0000
# iprec_at_recall_0.20  	16	0.0000
# iprec_at_recall_0.30  	16	0.0000
# iprec_at_recall_0.40  	16	0.0000
# iprec_at_recall_0.50  	16	0.0000
# iprec_at_recall_0.60  	16	0.0000
# iprec_at_recall_0.70  	16	0.0000
# iprec_at_recall_0.80  	16	0.0000
# iprec_at_recall_0.90  	16	0.0000
# iprec_at_recall_1.00  	16	0.0000
# P_5                   	16	0.0000
# P_10                  	16	0.0000
# P_15                  	16	0.0000
# P_20                  	16	0.0000
# P_30                  	16	0.0000
# P_100                 	16	0.0000
# P_200                 	16	0.0000
# P_500                 	16	0.0000
# P_1000                	16	0.0000
# num_ret               	18	32
# num_rel               	18	1
# num_rel_ret           	18	1
# map                   	18	1.0000
# Rprec                 	18	1.0000
# bpref                 	18	1.0000
# recip_rank            	18	1.0000
# iprec_at_recall_0.00  	18	1.0000
# iprec_at_recall_0.10  	18	1.0000
# iprec_at_recall_0.20  	18	1.0000
# iprec_at_recall_0.30  	18	1.0000
# iprec_at_recall_0.40  	18	1.0000
# iprec_at_recall_0.50  	18	1.0000
# iprec_at_recall_0.60  	18	1.0000
# iprec_at_recall_0.70  	18	1.0000
# iprec_at_recall_0.80  	18	1.0000
# iprec_at_recall_0.90  	18	1.0000
# iprec_at_recall_1.00  	18	1.0000
# P_5                   	18	0.2000
# P_10                  	18	0.1000
# P_15                  	18	0.0667
# P_20                  	18	0.0500
# P_30                  	18	0.0333
# P_100                 	18	0.0100
# P_200                 	18	0.0050
# P_500                 	18	0.0020
# P_1000                	18	0.0010
# num_ret               	19	5
# num_rel               	19	2
# num_rel_ret           	19	1
# map                   	19	0.5000
# Rprec                 	19	0.5000
# bpref                 	19	0.5000
# recip_rank            	19	1.0000
# iprec_at_recall_0.00  	19	1.0000
# iprec_at_recall_0.10  	19	1.0000
# iprec_at_recall_0.20  	19	1.0000
# iprec_at_recall_0.30  	19	1.0000
# iprec_at_recall_0.40  	19	1.0000
# iprec_at_recall_0.50  	19	1.0000
# iprec_at_recall_0.60  	19	0.0000
# iprec_at_recall_0.70  	19	0.0000
# iprec_at_recall_0.80  	19	0.0000
# iprec_at_recall_0.90  	19	0.0000
# iprec_at_recall_1.00  	19	0.0000
# P_5                   	19	0.2000
# P_10                  	19	0.1000
# P_15                  	19	0.0667
# P_20                  	19	0.0500
# P_30                  	19	0.0333
# P_100                 	19	0.0100
# P_200                 	19	0.0050
# P_500                 	19	0.0020
# P_1000                	19	0.0010
# num_ret               	2	13
# num_rel               	2	2
# num_rel_ret           	2	1
# map                   	2	0.5000
# Rprec                 	2	0.5000
# bpref                 	2	0.5000
# recip_rank            	2	1.0000
# iprec_at_recall_0.00  	2	1.0000
# iprec_at_recall_0.10  	2	1.0000
# iprec_at_recall_0.20  	2	1.0000
# iprec_at_recall_0.30  	2	1.0000
# iprec_at_recall_0.40  	2	1.0000
# iprec_at_recall_0.50  	2	1.0000
# iprec_at_recall_0.60  	2	0.0000
# iprec_at_recall_0.70  	2	0.0000
# iprec_at_recall_0.80  	2	0.0000
# iprec_at_recall_0.90  	2	0.0000
# iprec_at_recall_1.00  	2	0.0000
# P_5                   	2	0.2000
# P_10                  	2	0.1000
# P_15                  	2	0.0667
# P_20                  	2	0.0500
# P_30                  	2	0.0333
# P_100                 	2	0.0100
# P_200                 	2	0.0050
# P_500                 	2	0.0020
# P_1000                	2	0.0010
# num_ret               	22	86
# num_rel               	22	1
# num_rel_ret           	22	1
# map                   	22	0.0526
# Rprec                 	22	0.0000
# bpref                 	22	0.0000
# recip_rank            	22	0.0526
# iprec_at_recall_0.00  	22	0.0526
# iprec_at_recall_0.10  	22	0.0526
# iprec_at_recall_0.20  	22	0.0526
# iprec_at_recall_0.30  	22	0.0526
# iprec_at_recall_0.40  	22	0.0526
# iprec_at_recall_0.50  	22	0.0526
# iprec_at_recall_0.60  	22	0.0526
# iprec_at_recall_0.70  	22	0.0526
# iprec_at_recall_0.80  	22	0.0526
# iprec_at_recall_0.90  	22	0.0526
# iprec_at_recall_1.00  	22	0.0526
# P_5                   	22	0.0000
# P_10                  	22	0.0000
# P_15                  	22	0.0000
# P_20                  	22	0.0500
# P_30                  	22	0.0333
# P_100                 	22	0.0100
# P_200                 	22	0.0050
# P_500                 	22	0.0020
# P_1000                	22	0.0010
# num_ret               	24	24
# num_rel               	24	1
# num_rel_ret           	24	1
# map                   	24	1.0000
# Rprec                 	24	1.0000
# bpref                 	24	1.0000
# recip_rank            	24	1.0000
# iprec_at_recall_0.00  	24	1.0000
# iprec_at_recall_0.10  	24	1.0000
# iprec_at_recall_0.20  	24	1.0000
# iprec_at_recall_0.30  	24	1.0000
# iprec_at_recall_0.40  	24	1.0000
# iprec_at_recall_0.50  	24	1.0000
# iprec_at_recall_0.60  	24	1.0000
# iprec_at_recall_0.70  	24	1.0000
# iprec_at_recall_0.80  	24	1.0000
# iprec_at_recall_0.90  	24	1.0000
# iprec_at_recall_1.00  	24	1.0000
# P_5                   	24	0.2000
# P_10                  	24	0.1000
# P_15                  	24	0.0667
# P_20                  	24	0.0500
# P_30                  	24	0.0333
# P_100                 	24	0.0100
# P_200                 	24	0.0050
# P_500                 	24	0.0020
# P_1000                	24	0.0010
# num_ret               	26	52
# num_rel               	26	3
# num_rel_ret           	26	2
# map                   	26	0.0778
# Rprec                 	26	0.0000
# bpref                 	26	0.0000
# recip_rank            	26	0.1667
# iprec_at_recall_0.00  	26	0.1667
# iprec_at_recall_0.10  	26	0.1667
# iprec_at_recall_0.20  	26	0.1667
# iprec_at_recall_0.30  	26	0.1667
# iprec_at_recall_0.40  	26	0.0667
# iprec_at_recall_0.50  	26	0.0667
# iprec_at_recall_0.60  	26	0.0667
# iprec_at_recall_0.70  	26	0.0667
# iprec_at_recall_0.80  	26	0.0000
# iprec_at_recall_0.90  	26	0.0000
# iprec_at_recall_1.00  	26	0.0000
# P_5                   	26	0.0000
# P_10                  	26	0.1000
# P_15                  	26	0.0667
# P_20                  	26	0.0500
# P_30                  	26	0.0667
# P_100                 	26	0.0200
# P_200                 	26	0.0100
# P_500                 	26	0.0040
# P_1000                	26	0.0020
# num_ret               	28	64
# num_rel               	28	2
# num_rel_ret           	28	2
# map                   	28	0.2083
# Rprec                 	28	0.0000
# bpref                 	28	0.0000
# recip_rank            	28	0.1667
# iprec_at_recall_0.00  	28	0.2500
# iprec_at_recall_0.10  	28	0.2500
# iprec_at_recall_0.20  	28	0.2500
# iprec_at_recall_0.30  	28	0.2500
# iprec_at_recall_0.40  	28	0.2500
# iprec_at_recall_0.50  	28	0.2500
# iprec_at_recall_0.60  	28	0.2500
# iprec_at_recall_0.70  	28	0.2500
# iprec_at_recall_0.80  	28	0.2500
# iprec_at_recall_0.90  	28	0.2500
# iprec_at_recall_1.00  	28	0.2500
# P_5                   	28	0.0000
# P_10                  	28	0.2000
# P_15                  	28	0.1333
# P_20                  	28	0.1000
# P_30                  	28	0.0667
# P_100                 	28	0.0200
# P_200                 	28	0.0100
# P_500                 	28	0.0040
# P_1000                	28	0.0020
# num_ret               	4	40
# num_rel               	4	4
# num_rel_ret           	4	3
# map                   	4	0.5375
# Rprec                 	4	0.5000
# bpref                 	4	0.5000
# recip_rank            	4	1.0000
# iprec_at_recall_0.00  	4	1.0000
# iprec_at_recall_0.10  	4	1.0000
# iprec_at_recall_0.20  	4	1.0000
# iprec_at_recall_0.30  	4	1.0000
# iprec_at_recall_0.40  	4	1.0000
# iprec_at_recall_0.50  	4	1.0000
# iprec_at_recall_0.60  	4	0.1500
# iprec_at_recall_0.70  	4	0.1500
# iprec_at_recall_0.80  	4	0.0000
# iprec_at_recall_0.90  	4	0.0000
# iprec_at_recall_1.00  	4	0.0000
# P_5                   	4	0.4000
# P_10                  	4	0.2000
# P_15                  	4	0.1333
# P_20                  	4	0.1500
# P_30                  	4	0.1000
# P_100                 	4	0.0300
# P_200                 	4	0.0150
# P_500                 	4	0.0060
# P_1000                	4	0.0030
# num_ret               	6	15
# num_rel               	6	1
# num_rel_ret           	6	0
# map                   	6	0.0000
# Rprec                 	6	0.0000
# bpref                 	6	0.0000
# recip_rank            	6	0.0000
# iprec_at_recall_0.00  	6	0.0000
# iprec_at_recall_0.10  	6	0.0000
# iprec_at_recall_0.20  	6	0.0000
# iprec_at_recall_0.30  	6	0.0000
# iprec_at_recall_0.40  	6	0.0000
# iprec_at_recall_0.50  	6	0.0000
# iprec_at_recall_0.60  	6	0.0000
# iprec_at_recall_0.70  	6	0.0000
# iprec_at_recall_0.80  	6	0.0000
# iprec_at_recall_0.90  	6	0.0000
# iprec_at_recall_1.00  	6	0.0000
# P_5                   	6	0.0000
# P_10                  	6	0.0000
# P_15                  	6	0.0000
# P_20                  	6	0.0000
# P_30                  	6	0.0000
# P_100                 	6	0.0000
# P_200                 	6	0.0000
# P_500                 	6	0.0000
# P_1000                	6	0.0000
# num_ret               	7	14
# num_rel               	7	3
# num_rel_ret           	7	0
# map                   	7	0.0000
# Rprec                 	7	0.0000
# bpref                 	7	0.0000
# recip_rank            	7	0.0000
# iprec_at_recall_0.00  	7	0.0000
# iprec_at_recall_0.10  	7	0.0000
# iprec_at_recall_0.20  	7	0.0000
# iprec_at_recall_0.30  	7	0.0000
# iprec_at_recall_0.40  	7	0.0000
# iprec_at_recall_0.50  	7	0.0000
# iprec_at_recall_0.60  	7	0.0000
# iprec_at_recall_0.70  	7	0.0000
# iprec_at_recall_0.80  	7	0.0000
# iprec_at_recall_0.90  	7	0.0000
# iprec_at_recall_1.00  	7	0.0000
# P_5                   	7	0.0000
# P_10                  	7	0.0000
# P_15                  	7	0.0000
# P_20                  	7	0.0000
# P_30                  	7	0.0000
# P_100                 	7	0.0000
# P_200                 	7	0.0000
# P_500                 	7	0.0000
# P_1000                	7	0.0000
# num_ret               	9	27
# num_rel               	9	1
# num_rel_ret           	9	1
# map                   	9	0.0556
# Rprec                 	9	0.0000
# bpref                 	9	0.0000
# recip_rank            	9	0.0556
# iprec_at_recall_0.00  	9	0.0556
# iprec_at_recall_0.10  	9	0.0556
# iprec_at_recall_0.20  	9	0.0556
# iprec_at_recall_0.30  	9	0.0556
# iprec_at_recall_0.40  	9	0.0556
# iprec_at_recall_0.50  	9	0.0556
# iprec_at_recall_0.60  	9	0.0556
# iprec_at_recall_0.70  	9	0.0556
# iprec_at_recall_0.80  	9	0.0556
# iprec_at_recall_0.90  	9	0.0556
# iprec_at_recall_1.00  	9	0.0556
# P_5                   	9	0.0000
# P_10                  	9	0.0000
# P_15                  	9	0.0000
# P_20                  	9	0.0500
# P_30                  	9	0.0333
# P_100                 	9	0.0100
# P_200                 	9	0.0050
# P_500                 	9	0.0020
# P_1000                	9	0.0010
# runid                 	all	test
# num_q                 	all	15
# num_ret               	all	488
# num_rel               	all	35
# num_rel_ret           	all	15
# map                   	all	0.3455
# gm_map                	all	0.0191
# Rprec                 	all	0.3000
# bpref                 	all	0.3000
# recip_rank            	all	0.4461
# iprec_at_recall_0.00  	all	0.4517
# iprec_at_recall_0.10  	all	0.4517
# iprec_at_recall_0.20  	all	0.4517
# iprec_at_recall_0.30  	all	0.4517
# iprec_at_recall_0.40  	all	0.4450
# iprec_at_recall_0.50  	all	0.4450
# iprec_at_recall_0.60  	all	0.2550
# iprec_at_recall_0.70  	all	0.2550
# iprec_at_recall_0.80  	all	0.2405
# iprec_at_recall_0.90  	all	0.2405
# iprec_at_recall_1.00  	all	0.2405
# P_5                   	all	0.1067
# P_10                  	all	0.0733
# P_15                  	all	0.0489
# P_20                  	all	0.0467
# P_30                  	all	0.0333
# P_100                 	all	0.0100
# P_200                 	all	0.0050
# P_500                 	all	0.0020
# P_1000                	all	0.0010

# %% [markdown]
# ### Q3 (c): Provide answer to Q3 (c) here [markdown cell]

# %% [markdown]
# Modifications made: Stemming and Lower Casing
#
# Overall improvements were seen with all queries - more documents were retrieved, and the number of retrieved relevant documents doubled. This improvement is seen across all measures in all queries, including MAP, RPrec, recip_rank, and precision at recall levels.
#
# For query 4, the number of false negatives decreased since only one relevant document was not retrieved. MAP also increased from 0.03 to over 0.5, and RPrec increased from 0 to 0.5. However, the number of retrieved documents increased dramatically, from 12 to 40, and thus the number of false positives also increased dramatically.

# %% [markdown]
# ### Q3 (d): Provide answer to Q3 (d) here [markdown cell]

# %% [markdown]
# Yes

# %% [markdown]
# ### Q3 (e): Provide answer to Q3 (e) here [markdown cell]

# %% [markdown]
# Yes

# %% [markdown]
# ### Q3 (f): Provide answer to Q3 (f) here [markdown cell]

# %% [markdown]
# Although my idea improved precision measures such as MAP and RPrec, the number of retrieved and irrelevant documents (false positives) skyrocketed. Thus, I don't think this was a particularly useful improvement.

# %% [markdown]
# ## Question 4 (Graduate Students)

# %%
GRAD_STUDENT = False # change to True if you are a grad student

# %% [markdown]
# ### Q4 (a): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# ### Q4 (b): Write your code below

# %%
# Put your code for creating the index here (you can add more cells).
# Make sure you save the final index in the variable INDEX_Q4, your query parser in QP_Q4, and your searcher in SEARCHER_Q4

# %%
INDEX_Q4 = None # Replace None with your index for Q4
QP_Q4 = None # Replace None with your query parser for Q4
SEARCHER_Q4 = None # Replace None with your searcher for Q4

# %% [markdown]
# ### Q4 (c): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# ### Q4 (d): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# ### Q4 (e): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# ### Q4 (f): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# ## Validation

# %%
# Run the following cells to make sure your code returns the correct value types

# %%
from whoosh.index import FileIndex
from whoosh.qparser import QueryParser
from whoosh.searching import Searcher
import os.path

# %% [markdown]
# ### Q2 Validation

# %%
assert(isinstance(INDEX_Q2, FileIndex)), "Index Type"
assert(isinstance(QP_Q2, QueryParser)), "Query Parser Type"
assert(isinstance(SEARCHER_Q2, Searcher)), "Searcher Type"
print("Q2 Types Validated")
# Out:
# Q2 Types Validated

# %% [markdown]
# ### Q3 Validation

# %%
assert(isinstance(INDEX_Q3, FileIndex)), "Index Type"
assert(isinstance(QP_Q3, QueryParser)), "Query Parser Type"
assert(isinstance(SEARCHER_Q3, Searcher)), "Searcher Type"
print("Q3 Types Validated")
# Out:
# Q3 Types Validated

# %% [markdown]
# ### Q4 Validation (Graduate Students)

# %%
assert((not GRAD_STUDENT) or isinstance(INDEX_Q4, FileIndex)), "Index Type"
assert((not GRAD_STUDENT) or isinstance(QP_Q4, QueryParser)), "Query Parser Type"
assert((not GRAD_STUDENT) or isinstance(SEARCHER_Q4, Searcher)), "Searcher Type"
print("Q4 Types Validated")
